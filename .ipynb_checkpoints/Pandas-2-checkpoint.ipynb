# %% [markdown]
# ## Working with missing data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset/titanic.csv",sep=",",header=0,index_col=None)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.isnull()
# Out:
#     PassengerId Survived Pclass   Name    Sex    Age  SibSp  Parch Ticket  \
# 0         False    False  False  False  False  False  False  False  False
# 1         False    False  False  False  False  False  False  False  False
# 2         False    False  False  False  False  False  False  False  False
# 3         False    False  False  False  False  False  False  False  False
# 4         False    False  False  False  False  False  False  False  False
# 5         False    False  False  False  False   True  False  False  False
# 6         False    False  False  False  False  False  False  False  False
# 7         False    False  False  False  False  False  False  False  False
# 8         False    False  False  False  False  False  False  False  False
# 9         False    False  False  False  False  False  False  False  False
# 10        False    False  False  False  False  False  False  False  False
# 11        False    False  False  False  False  False  False  False  False
# ...

# %%
# df.loc[0]=np.nan
# df

# %%
# df["Age"] = df["Age"].fillna(df["Age"].mean())
# df

# %%
df.dropna(axis=0).describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %% [markdown]
# # Merge, join, and concatenate

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
# /home/ayush/.local/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# ...

# %%
df.columns
# Out:
# Index([u'PassengerId', u'Survived', u'Pclass', u'Name', u'Sex', u'Age',
#        u'SibSp', u'Parch', u'Ticket', u'Fare', u'Cabin', u'Embarked'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %% [markdown]
# ## Concatenate

# %%
 df1 = pd.DataFrame({ 'A': ['A0', 'A1', 'A2', 'A3'],
                      'B': ['B0', 'B1', 'B2', 'B3'],
                      'C': ['C0', 'C1', 'C2', 'C3'],
                      'D': ['D0', 'D1', 'D2', 'D3']},
                      index=[0, 1, 2, 3])

df2 = pd.DataFrame({ 'D': ['A4', 'A5', 'A6', 'A7'],
                     'F': ['B4', 'B5', 'B6', 'B7'],
                     'G': ['C4', 'C5', 'C6', 'C7'],
                     'H': ['D4', 'D5', 'D6', 'D7']},
                      index=[2, 3, 8, 9])
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     D   F   G   H
# 2  A4  B4  C4  D4
# 3  A5  B5  C5  D5
# 8  A6  B6  C6  D6
# 9  A7  B7  C7  D7

# %%
pd.concat([df1,df2],axis=0,join="outer")
# Out:
#      A    B    C   D    F    G    H
# 0   A0   B0   C0  D0  NaN  NaN  NaN
# 1   A1   B1   C1  D1  NaN  NaN  NaN
# 2   A2   B2   C2  D2  NaN  NaN  NaN
# 3   A3   B3   C3  D3  NaN  NaN  NaN
# 2  NaN  NaN  NaN  A4   B4   C4   D4
# 3  NaN  NaN  NaN  A5   B5   C5   D5
# 8  NaN  NaN  NaN  A6   B6   C6   D6
# 9  NaN  NaN  NaN  A7   B7   C7   D7

# %%
pd.concat([df1,df2],axis=0,join="inner")
# Out:
#     D
# 0  D0
# 1  D1
# 2  D2
# 3  D3
# 2  A4
# 3  A5
# 8  A6
# 9  A7

# %%
pd.concat([df1,df2],axis=1,join="outer")
# Out:
#      A    B    C    D    D    F    G    H
# 0   A0   B0   C0   D0  NaN  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN  NaN
# 2   A2   B2   C2   D2   A4   B4   C4   D4
# 3   A3   B3   C3   D3   A5   B5   C5   D5
# 8  NaN  NaN  NaN  NaN   A6   B6   C6   D6
# 9  NaN  NaN  NaN  NaN   A7   B7   C7   D7

# %%
pd.concat([df1,df2],axis=1,join="inner")
# Out:
#     A   B   C   D   D   F   G   H
# 2  A2  B2  C2  D2  A4  B4  C4  D4
# 3  A3  B3  C3  D3  A5  B5  C5  D5

# %% [markdown]
# ## Append

# %%
df1.append(df2,ignore_index='True')
# Out:
#      A    B    C   D    F    G    H
# 0   A0   B0   C0  D0  NaN  NaN  NaN
# 1   A1   B1   C1  D1  NaN  NaN  NaN
# 2   A2   B2   C2  D2  NaN  NaN  NaN
# 3   A3   B3   C3  D3  NaN  NaN  NaN
# 4  NaN  NaN  NaN  A4   B4   C4   D4
# 5  NaN  NaN  NaN  A5   B5   C5   D5
# 6  NaN  NaN  NaN  A6   B6   C6   D6
# 7  NaN  NaN  NaN  A7   B7   C7   D7

# %%
s1 = pd.Series(['X0', 'X1', 'X2', 'X3'], index=['A', 'B', 'C', 'D'])
df1.append(s1, ignore_index=True)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  X0  X1  X2  X3

# %% [markdown]
# # Merging/Joining

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
right = pd.DataFrame({'key': ['K2', 'K3', 'K4', 'K5'],
                      'C': ['C0', 'C1', 'C2', 'C3'],
                      'D': ['D0', 'D1', 'D2', 'D3']})
    
left
# Out:
#     A   B key
# 0  A0  B0  K0
# 1  A1  B1  K1
# 2  A2  B2  K2
# 3  A3  B3  K3

# %%
pd.merge(left,right,on='key',how="inner",indicator='indicator_column')
# Out:
#     A   B key   C   D indicator_column
# 0  A2  B2  K2  C0  D0             both
# 1  A3  B3  K3  C1  D1             both

# %%
pd.merge(left,right,on='key',how="outer",indicator='indicator_column')
# Out:
#      A    B key    C    D indicator_column
# 0   A0   B0  K0  NaN  NaN        left_only
# 1   A1   B1  K1  NaN  NaN        left_only
# 2   A2   B2  K2   C0   D0             both
# 3   A3   B3  K3   C1   D1             both
# 4  NaN  NaN  K4   C2   D2       right_only
# 5  NaN  NaN  K5   C3   D3       right_only

# %%
pd.merge(left,right,on="key",how='left',indicator='indicator_column')
# Out:
#     A   B key    C    D indicator_column
# 0  A0  B0  K0  NaN  NaN        left_only
# 1  A1  B1  K1  NaN  NaN        left_only
# 2  A2  B2  K2   C0   D0             both
# 3  A3  B3  K3   C1   D1             both

# %%
pd.merge(left,right,on="key",how='right',indicator='indicator_column')
# Out:
#      A    B key   C   D indicator_column
# 0   A2   B2  K2  C0  D0             both
# 1   A3   B3  K3  C1  D1             both
# 2  NaN  NaN  K4  C2  D2       right_only
# 3  NaN  NaN  K5  C3  D3       right_only

# %% [markdown]
# ## Join

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                      'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2'])
right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                       'D': ['D0', 'D2', 'D3']},
                       index=['K0', 'K2', 'K3'])

# %%
left.join(right,how="inner")
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2

# %%
left.join(right,how="outer")
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %% [markdown]
# # Working with text

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss. Marguerite Rut
# 11                              Bonnell, Miss. Elizabeth
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
df["Name"].str.split(",")
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
# 5                                    [Moran,  Mr. James]
# 6                             [McCarthy,  Mr. Timothy J]
# 7                      [Palsson,  Master. Gosta Leonard]
# 8      [Johnson,  Mrs. Oscar W (Elisabeth Vilhelmina ...
# 9                 [Nasser,  Mrs. Nicholas (Adele Achem)]
# 10                    [Sandstrom,  Miss. Marguerite Rut]
# 11                           [Bonnell,  Miss. Elizabeth]
# 12                     [Saundercock,  Mr. William Henry]
# 13                        [Andersson,  Mr. Anders Johan]
# 14               [Vestrom,  Miss. Hulda Amanda Adolfina]
# 15                   [Hewlett,  Mrs. (Mary D Kingcome) ]
# ...

# %%
df["Name"].str.cat()
# Out:
# 'Braund, Mr. Owen HarrisCumings, Mrs. John Bradley (Florence Briggs Thayer)Heikkinen, Miss. LainaFutrelle, Mrs. Jacques Heath (Lily May Peel)Allen, Mr. William HenryMoran, Mr. JamesMcCarthy, Mr. Timothy JPalsson, Master. Gosta LeonardJohnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)Nasser, Mrs. Nicholas (Adele Achem)Sandstrom, Miss. Marguerite RutBonnell, Miss. ElizabethSaundercock, Mr. William HenryAndersson, Mr. Anders JohanVestrom, Miss. Hulda Amanda AdolfinaHewlett, Mrs. (Mary D Kingcome) Rice, Master. EugeneWilliams, Mr. Charles EugeneVander Planke, Mrs. Julius (Emelia Maria Vandemoortele)Masselmani, Mrs. FatimaFynney, Mr. Joseph JBeesley, Mr. LawrenceMcGowan, Miss. Anna "Annie"Sloper, Mr. William ThompsonPalsson, Miss. Torborg DaniraAsplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)Emir, Mr. Farred ChehabFortune, Mr. Charles AlexanderO\'Dwyer, Miss. Ellen "Nellie"Todoroff, Mr. LalioUruchurtu, Don. Manuel ESpencer, Mrs. William Augustus (Marie Eugenie)Glynn, Miss. Mary Ag
# ...

# %% [markdown]
# # Apply,map,Applymap

# %% [markdown]
# ## Apply
# dataframe.apply(function,axis=('0' or '1'))

# %%
df_new = df.loc[:,"PassengerId":"Pclass"]

# %%
df_new.apply(np.sum,axis=0)
# Out:
# PassengerId    397386
# Survived          342
# Pclass           2057
# dtype: int64

# %% [markdown]
# ## map
# Applied to Series

# %%
df["Age"].map(lambda x : x+100)
# Out:
# 0      122.0
# 1      138.0
# 2      126.0
# 3      135.0
# 4      135.0
# 5        NaN
# 6      154.0
# 7      102.0
# 8      127.0
# 9      114.0
# 10     104.0
# 11     158.0
# 12     120.0
# 13     139.0
# 14     114.0
# 15     155.0
# 16     102.0
# 17       NaN
# 18     131.0
# 19       NaN
# 20     135.0
# 21     134.0
# 22     115.0
# 23     128.0
# 24     108.0
# 25     138.0
# 26       NaN
# 27     119.0
# 28       NaN
# 29       NaN
#        ...
# 861    121.0
# 862    148.0
# 863      NaN
# 864    124.0
# 865    142.0
# 866    127.0
# 867    131.0
# 868      NaN
# 869    104.0
# 870    126.0
# 871    147.0
# 872    133.0
# 873    147.0
# 874    128.0
# 875    115.0
# 876    120.0
# 877    119.0
# 878      NaN
# 879    156.0
# 880    125.0
# 881    133.0
# 882    122.0
# 883    128.0
# 884    125.0
# 885    139.0
# 886    127.0
# 887    119.0
# 888      NaN
# 889    126.0
# 890    132.0
# Name: Age, dtype: float64

# %% [markdown]
# ## Applymap
# Applied elementwise to all data points

# %%
df.applymap(lambda x : str(x)+"1")
# Out:
#     PassengerId Survived Pclass  \
# 0            11       01     31
# 1            21       11     11
# 2            31       11     31
# 3            41       11     11
# 4            51       01     31
# 5            61       01     31
# 6            71       01     11
# 7            81       01     31
# 8            91       11     31
# 9           101       11     21
# 10          111       11     31
# 11          121       11     11
# 12          131       01     31
# 13          141       01     31
# 14          151       01     31
# 15          161       11     21
# 16          171       01     31
# 17          181       11     21
# 18          191       01     31
# 19          201       11     31
# 20          211       01     21
# 21          221       11     21
# 22          231       11     31
# 23          241       11     11
# 24          251       01     31
# 25          261       11     31
# 26          271       01     31
# 27          281       01     11
# ...

# %% [markdown]
# # Categorical Data

# %%
df["Sex"] = df["Sex"].astype("category")
# Out:
# pandas.core.series.Series

# %%
df["Sex"].cat.categories
# Out:
# Index([u'female', u'male'], dtype='object')

# %%
df["Sex"].cat.codes
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
# 5      1
# 6      1
# 7      1
# 8      0
# 9      0
# 10     0
# 11     0
# 12     1
# 13     1
# 14     0
# 15     0
# 16     1
# 17     1
# 18     0
# 19     0
# 20     1
# 21     1
# 22     0
# 23     1
# 24     0
# 25     0
# 26     1
# 27     1
# 28     0
# 29     1
#       ..
# 861    1
# 862    0
# 863    0
# 864    1
# 865    0
# 866    0
# 867    1
# 868    1
# 869    1
# 870    1
# 871    0
# 872    1
# 873    1
# 874    0
# 875    0
# 876    1
# 877    1
# 878    1
# 879    0
# 880    0
# 881    1
# 882    0
# 883    1
# 884    1
# 885    0
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# dtype: int8

# %%
df.Pclass = df.Pclass.astype("category")

# %%
df.Pclass.cat.categories
# Out:
# Int64Index([1, 2, 3], dtype='int64')

# %%
df.Pclass.cat.codes
# Out:
# 0      2
# 1      0
# 2      2
# 3      0
# 4      2
# 5      2
# 6      0
# 7      2
# 8      2
# 9      1
# 10     2
# 11     0
# 12     2
# 13     2
# 14     2
# 15     1
# 16     2
# 17     1
# 18     2
# 19     2
# 20     1
# 21     1
# 22     2
# 23     0
# 24     2
# 25     2
# 26     2
# 27     0
# 28     2
# 29     2
#       ..
# 861    1
# 862    0
# 863    2
# 864    1
# 865    1
# 866    1
# 867    0
# 868    2
# 869    2
# 870    2
# 871    0
# 872    0
# 873    2
# 874    1
# 875    2
# 876    2
# 877    2
# 878    2
# 879    0
# 880    1
# 881    2
# 882    2
# 883    1
# 884    2
# 885    2
# 886    1
# 887    0
# 888    2
# 889    0
# 890    2
# dtype: int8

# %%
s = pd.Series([1,2,3,1,2,1,3]).astype('category',categories=[1,2,3],ordered=True)

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    1
# 4    2
# 5    1
# 6    3
# dtype: category
# Categories (3, int64): [1 < 2 < 3]
